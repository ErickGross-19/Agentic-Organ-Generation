# %% [markdown]
# # Single Agent Organ Generator V1 - Updated Workflow
#
# This notebook demonstrates the workflow with **dynamic question variance** feature.

# %% [markdown]
# ## 1. Setup

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from automation import *
print('All imports successful!')

# %% [markdown]
# ## 2. Dynamic Question Variance

# %%
for intent in ['liver vascular', 'kidney renal', 'lung pulmonary', 'heart coronary', 'generic tube']:
    print(f'{intent}: {detect_organ_type(intent)}')

# %%
for organ in ['liver', 'kidney', 'lung', 'heart']:
    q = get_tailored_questions(f'{organ} network')
    print(f"{organ}: {q['C']['name']}")

# %% [markdown]
# ## 3. Workflow States

# %%
for s in WorkflowState:
    print(s.value)

# %% [markdown]
# ## 4. Question Groups

# %%
for k, v in QUESTION_GROUPS.items():
    print(f"Group {k}: {v['name']}")

# %% [markdown]
# ## 5. Organ Variants

# %%
for organ, v in ORGAN_QUESTION_VARIANTS.items():
    print(f"{organ}: {v['description'][:50]}...")
